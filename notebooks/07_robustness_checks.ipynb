# %% [markdown]
# # 07 - Robustness Checks
#
# Re-run the main results under alternative windows, samples, and model distributions.

# %%
import pandas as pd

checks = pd.DataFrame(
    {
        "robustness_check": [
            "Rolling HV windows",
            "Pre/post COVID split",
            "GARCH with Student-t innovations",
            "Alternative benchmark window",
            "Exclude extreme return days",
        ],
        "implementation": [
            "Repeat benchmark comparison using 10d, 30d, and 60d volatility windows.",
            "Split sample at 2020-03-24 and compare model rankings.",
            "Re-fit GARCH, EGARCH, and GJR-GARCH with dist='t'.",
            "Use 10d and 60d realized volatility-of-volatility benchmarks.",
            "Winsorize returns or remove top/bottom 1% observations.",
        ],
    }
)
checks
# Out:
#                    robustness_check  \
# 0                Rolling HV windows
# 1              Pre/post COVID split
# 2  GARCH with Student-t innovations
# 3      Alternative benchmark window
# 4       Exclude extreme return days
#
#                                       implementation
# 0  Repeat benchmark comparison using 10d, 30d, an...
# 1  Split sample at 2020-03-24 and compare model r...
# 2  Re-fit GARCH, EGARCH, and GJR-GARCH with dist=...
# 3  Use 10d and 60d realized volatility-of-volatil...
# 4  Winsorize returns or remove top/bottom 1% obse...
