# %% [markdown]
# # 06 - Spillover Analysis Template
#
# Add NIFTY VIX and VIX files here, then run correlation and Granger causality tests.

# %%
from pathlib import Path
import pandas as pd

required_files = {
    "NIFTY VIX": Path("nifty_vix.csv"),
    "S&P 500 VIX": Path("vix_sp500.csv"),
    "NRB T-bill rates": Path("nrb_tbill_rates.csv"),
}

for name, path in required_files.items():
    print(f"{name}: {'FOUND' if path.exists() else 'MISSING'} - {path}")
# Out:
# NIFTY VIX: MISSING - nifty_vix.csv
# S&P 500 VIX: MISSING - vix_sp500.csv
# NRB T-bill rates: MISSING - nrb_tbill_rates.csv

# %%
# Expected columns:
# nifty_vix.csv      -> date, nifty_vix
# vix_sp500.csv      -> date, vix
# nrb_tbill_rates.csv -> date, tbill_rate
#
# Once files are available:
# 1. Merge external series with data_vov_methods.csv
# 2. Correlate NEPSE volatility with NIFTY VIX and VIX
# 3. Test Granger causality: does India's volatility predict Nepal's?
